# %%
# import pandas as pd
# pd.read_csv('titanic.csv')


# data = pd.read_csv("https://github.com/datasciencedojo/datasets/blob/master/titanic.csv")

# print(data.toString)
# data.head()

# %%
import pandas as pd

# Provide the direct link to the raw CSV file on GitHub
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

# Read the CSV file from the URL
data = pd.read_csv(url)

# Display the first few rows of the DataFrame
# data

# data.dtypes

# data.info()

# data.describe()

# data[["Name","Sex" , "Ticket" , "Cabin" , "Embarked"]]

# %%
# fetching and processing categorical ddata

# data



# data.dtypes
# data.dtypes == "object"
# type(data.dtypes == "object")

# data.dtypes[data.dtypes == "object"]
# data.dtypes[data.dtypes == "object"].index

# data[data.dtypes[data.dtypes == "object"].index]

# data[data.dtypes[data.dtypes == "object"].index].describe()

# data["Survived"]

# data["Survived"] == 0

# data[data["Survived"] == 0]

# (data["Survived"] == 0) & (data["Sex"] == "male")

# len((data["Survived"] == 0) & (data["Sex"] == "male"))

# data[(data["Survived"] == 0) & (data["Sex"] == "male")]


# len(data[(data["Survived"] == 0) & (data["Sex"] == "male")])

# len(data[(data["Survived"] == 0) & (data["Sex"] == "female")])





 # Q1  => male onboarded on ship

# data["Sex"] == "male" 
# data[data["Sex"] == "male"]
# len(data[data["Sex"] == "male"])


# Q2  => female onboarded on ship
# len(data[data["Sex"] == "female"])



# Q3 => Groupwise count
# data["Sex"].value_counts()



# Q4 => Name of person who has paid highest fare
# data["Fare"]
# max(data["Fare"])
# data["Fare"] == max(data["Fare"])

# x1 = data[data["Fare"] == max(data["Fare"])]
# x1
# x1['Name']
# x1[['Name']]


# Q5 => find the no. of person who have received cabin
# data
# data['Cabin'] 
# data['Cabin'].isnull()

# data['Cabin'].isnull() == False
# data[data['Cabin'].isnull() == False]
# len(data[data['Cabin'].isnull() == False])

# data[data['Cabin'] == 'nan']


# Q6 => Adding new-column to data
# data['new_col'] = "avi"
# data


# Q7 => dublicating perticular column
# data
# data['New_Name'] = data['Name']
# data



# Q8 => Delete a columnab

#    8.1 => temperory delete
# data.drop('new_col')
# data.drop('new_col',axis=1)
# data

#    8.2 => permanent delete
#      1-way
# data = data.drop('new_col',axis=1) 
#      2-way
# data.drop('New_Name',axis=1,inplace=True)
# data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd

# Provide the direct link to the raw CSV file on GitHub
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

# data = pd.read_csv(url)
# data['new_col'] = "avi"
# data

# %%
import pandas as pd

# Provide the direct link to the raw CSV file on GitHub
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

# data = pd.read_csv(url)
# data

# %% [markdown]
# ## Row-operations

# %%
import pandas as pd

# Provide the direct link to the raw CSV file on GitHub
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

data = pd.read_csv(url)

# Q!. => delete a pwrticula row
data.drop(0)
data.drop(0,inplace=True)
data



# Q2 => fetching perticular rowab
# data.iloc[3]

# data.loc[3]
# data.loc[3,['Survived','Age']]


# data.loc[101:105]
# data.loc[101:105,['Name','Fare']]
# data
# data.loc[3:4,['Fare','Cabin','Embarked']]
 
# data['Age'] >= 35

# data[data['Age'] > 35]



# Q9 => male=1,female=0
def fun1(x):
    if x == "female":
        return 0
    else:
        return 1

data['Gender'] = data['Sex'].apply(fun1)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...
